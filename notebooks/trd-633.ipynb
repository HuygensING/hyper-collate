// %%
%use hyper-collate
// Out:
// Welcome to HyperCollate 1.3.5-SNAPSHOT-3
// Using GraphViz: dot - graphviz version 2.40.1 (20161225.0304)
// <style>div.output_area pre {white-space: pre;} .rendered_html td {border: 1px solid}</style>

// %% [markdown]
// # Vincent's case

// %%
val wA = HC.importXMLWitness("A", "<e>well <subst><del>in his own way</del><add>at his own pace</add></subst>.</e>")
val wB = HC.importXMLWitness("B", "<e>well at his own gait.</e>")
val collationGraph = HC.collate(wA,wB)
collationGraph.asASCIITable(emphasizeWhitespace=true)
// Out:
// ┌───┬─────┬───────┬────────┬────────┬────────┬─┐
// │[A]│     │[+] at_│[+] his_│[+] own_│[+] pace│ │
// │   │well_│[-] in_│[-] his_│[-] own_│[-] way │.│
// ├───┼─────┼───────┼────────┼────────┼────────┼─┤
// │[B]│well_│at_    │his_    │own_    │gait    │.│
// └───┴─────┴───────┴────────┴────────┴────────┴─┘

// %%
collationGraph.asHtml()
// Out:
// <table border="1">
//             <tr><th style="background:lightgreen">A</th><td><span style="background-color:lightblue">well&nbsp;</span></td><td><del>in&nbsp;</del>&nbsp;<sup><span style="background-color:lightblue">at&nbsp;</span></sup></td><td><del>his&nbsp;</del>&nbsp;<sup><span style="background-color:lightblue">his&nbsp;</span></sup></td><td><del>own&nbsp;</del>&nbsp;<sup><span style="background-color:lightblue">own&nbsp;</span></sup></td><td><del>way</del>&nbsp;<sup>pace</sup></td><td><span style="background-color:lightblue">.</span></td></tr>
// <tr><th style="background:lightgreen">B</th><td><span style="background-color:lightblue">well&nbsp;</span></td><td><span style="background-color:lightblue">at&nbsp;</span></td><td><span style="background-color:lightblue">his&nbsp;</span></td><td><span style="background-color:lightblue">own&nbsp;</span></td><td>gait</td><td><span style="background-color:lightblue">.</span></td></tr>
//             </table>

// %%
collationGraph.show()

// %% [markdown]
// # 1: Duplicates in add en del branches
//
// Gewenste uitkomst: Moet alleen de add volgen.

// %%
val wA = HC.importXMLWitness("A", "<root>a long <subst><add>text that is very long</add><del>text that is different</del></subst></root>")
val wB = HC.importXMLWitness("B", "<root>a long text that is very long</root>")
val collationGraph = HC.collate(wA,wB)
collationGraph.asASCIITable()
// Out:
// ┌───┬──┬─────┬─────────┬─────────┬───────┬─────────────┬────────┐
// │[A]│  │     │[+]  text│[+]  that│[+]  is│[+]      very│        │
// │   │a │long │[-] text │[-] that │[-] is │[-] different│[+] long│
// ├───┼──┼─────┼─────────┼─────────┼───────┼─────────────┼────────┤
// │[B]│a │long │text     │that     │is     │very         │long    │
// └───┴──┴─────┴─────────┴─────────┴───────┴─────────────┴────────┘

// %%
collationGraph.asHtml()
// Out:
// <table border="1">
//             <tr><th style="background:lightgreen">A</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">long&nbsp;</span></td><td><sup><span style="background-color:lightblue">text&nbsp;</span></sup>&nbsp;<del>text&nbsp;</del></td><td><sup><span style="background-color:lightblue">that&nbsp;</span></sup>&nbsp;<del>that&nbsp;</del></td><td><sup><span style="background-color:lightblue">is&nbsp;</span></sup>&nbsp;<del>is&nbsp;</del></td><td><sup><span style="background-color:lightblue">very&nbsp;</span></sup>&nbsp;<del>different</del></td><td><sup><span style="background-color:lightblue">long</span></sup></td></tr>
// <tr><th style="background:lightgreen">B</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">long&nbsp;</span></td><td><span style="background-color:lightblue">text&nbsp;</span></td><td><span style="background-color:lightblue">that&nbsp;</span></td><td><span style="background-color:lightblue">is&nbsp;</span></td><td><span style="background-color:lightblue">very&nbsp;</span></td><td><span style="background-color:lightblue">long</span></td></tr>
//             </table>

// %%
collationGraph.show()

// %% [markdown]
// ## 1a: add/del reversed

// %%
val wA = HC.importXMLWitness("A", "<root>A long <subst><del>text that is different</del><add>text that is very long</add></subst>.</root>")
val wB = HC.importXMLWitness("B", "<root>A long text that is very long.</root>")
val collationGraph = HC.collate(wA,wB)
collationGraph.asASCIITable()
// Out:
// ┌───┬──┬─────┬─────────┬─────────┬───────┬─────────────┬────────┬─┐
// │[A]│  │     │[+]  text│[+]  that│[+]  is│[+]      very│        │ │
// │   │A │long │[-] text │[-] that │[-] is │[-] different│[+] long│.│
// ├───┼──┼─────┼─────────┼─────────┼───────┼─────────────┼────────┼─┤
// │[B]│A │long │text     │that     │is     │very         │long    │.│
// └───┴──┴─────┴─────────┴─────────┴───────┴─────────────┴────────┴─┘

// %%
collationGraph.asHtml()
// Out:
// <table border="1">
//             <tr><th style="background:lightgreen">A</th><td><span style="background-color:lightblue">A&nbsp;</span></td><td><span style="background-color:lightblue">long&nbsp;</span></td><td><del>text&nbsp;</del>&nbsp;<sup><span style="background-color:lightblue">text&nbsp;</span></sup></td><td><del>that&nbsp;</del>&nbsp;<sup><span style="background-color:lightblue">that&nbsp;</span></sup></td><td><del>is&nbsp;</del>&nbsp;<sup><span style="background-color:lightblue">is&nbsp;</span></sup></td><td><del>different</del>&nbsp;<sup><span style="background-color:lightblue">very&nbsp;</span></sup></td><td><sup><span style="background-color:lightblue">long</span></sup></td><td><span style="background-color:lightblue">.</span></td></tr>
// <tr><th style="background:lightgreen">B</th><td><span style="background-color:lightblue">A&nbsp;</span></td><td><span style="background-color:lightblue">long&nbsp;</span></td><td><span style="background-color:lightblue">text&nbsp;</span></td><td><span style="background-color:lightblue">that&nbsp;</span></td><td><span style="background-color:lightblue">is&nbsp;</span></td><td><span style="background-color:lightblue">very&nbsp;</span></td><td><span style="background-color:lightblue">long</span></td><td><span style="background-color:lightblue">.</span></td></tr>
//             </table>

// %%
collationGraph.show()

// %% [markdown]
// # 2: Add en del branches hebben beide interessante tokens, er zijn geen duplicates.
//
// Gewenste uitkomst:
//                 root volgen, daarna add, daarna del. Je switcht dan niet heen en weer van branches tijdens de alignment.

// %%
val wA = HC.importXMLWitness("A", "<root>a b <subst><add>c d e</add><del>f g</del></subst> h</root>")
val wB = HC.importXMLWitness("B", "<root>a b c d e f g h</root>")
val collationGraph = HC.collate(wA,wB)
collationGraph.asASCIITable()
// Out:
// ┌───┬──┬──┬──────┬──────┬─────┬──────┬─────┬─┬─┐
// │[A]│a │b │[+] c │[+] d │[+] e│[-] f │[-] g│ │h│
// ├───┼──┼──┼──────┼──────┼─────┼──────┼─────┼─┼─┤
// │[B]│a │b │c     │d     │e    │f     │g    │ │h│
// └───┴──┴──┴──────┴──────┴─────┴──────┴─────┴─┴─┘

// %%
collationGraph.asHtml()
// Out:
// <table border="1">
//             <tr><th style="background:lightgreen">A</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">b&nbsp;</span></td><td><sup><span style="background-color:lightblue">c&nbsp;</span></sup></td><td><sup><span style="background-color:lightblue">d&nbsp;</span></sup></td><td><sup><span style="background-color:lightblue">e</span></sup></td><td><del><span style="background-color:lightblue">f&nbsp;</span></del></td><td><del><span style="background-color:lightblue">g</span></del></td><td>&nbsp;</td><td><span style="background-color:lightblue">h</span></td></tr>
// <tr><th style="background:lightgreen">B</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">b&nbsp;</span></td><td><span style="background-color:lightblue">c&nbsp;</span></td><td><span style="background-color:lightblue">d&nbsp;</span></td><td><span style="background-color:lightblue">e&nbsp;</span></td><td><span style="background-color:lightblue">f&nbsp;</span></td><td><span style="background-color:lightblue">g&nbsp;</span></td><td></td><td><span style="background-color:lightblue">h</span></td></tr>
//             </table>

// %%
collationGraph.show()

// %% [markdown]
// # 3: Branches in branches
//
// Gewenste uitkomst:
//                 root volgen, dan de eerste subst/add, dan de tweede subs/add.

// %%
val wA = HC.importXMLWitness("A", "<root>a b <subst><add>c d e<subst><add>f g h</add><del>bla die bla</del></subst></add><del>f g</del></subst></root>")
val wB = HC.importXMLWitness("B", "<root>a b c d e f g h</root>")
val collationGraph = HC.collate(wA,wB)
collationGraph.asASCIITable()
// Out:
// ┌───┬──┬──┬──────┬──────┬─────┬────────┬────────┬───────┬──────┬─────┐
// │[A]│  │  │      │      │     │[+]    f│[+]    g│[+]   h│      │     │
// │   │a │b │[+] c │[+] d │[+] e│[-] bla │[-] die │[-] bla│[-] f │[-] g│
// ├───┼──┼──┼──────┼──────┼─────┼────────┼────────┼───────┼──────┼─────┤
// │[B]│a │b │c     │d     │e    │f       │g       │h      │      │     │
// └───┴──┴──┴──────┴──────┴─────┴────────┴────────┴───────┴──────┴─────┘

// %%
collationGraph.asHtml()
// Out:
// <table border="1">
//             <tr><th style="background:lightgreen">A</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">b&nbsp;</span></td><td><sup><span style="background-color:lightblue">c&nbsp;</span></sup></td><td><sup><span style="background-color:lightblue">d&nbsp;</span></sup></td><td><sup><span style="background-color:lightblue">e</span></sup></td><td><sup><span style="background-color:lightblue">f&nbsp;</span></sup>&nbsp;<del>bla&nbsp;</del></td><td><sup><span style="background-color:lightblue">g&nbsp;</span></sup>&nbsp;<del>die&nbsp;</del></td><td><sup><span style="background-color:lightblue">h</span></sup>&nbsp;<del>bla</del></td><td><del>f&nbsp;</del></td><td><del>g</del></td></tr>
// <tr><th style="background:lightgreen">B</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">b&nbsp;</span></td><td><span style="background-color:lightblue">c&nbsp;</span></td><td><span style="background-color:lightblue">d&nbsp;</span></td><td><span style="background-color:lightblue">e&nbsp;</span></td><td><span style="background-color:lightblue">f&nbsp;</span></td><td><span style="background-color:lightblue">g&nbsp;</span></td><td><span style="background-color:lightblue">h</span></td><td></td><td></td></tr>
//             </table>

// %%
collationGraph.show()

// %% [markdown]
// # 4. De beste match kan ook deels na de branch liggen.
//
// Gewenste uitkomst:
//                 root volgen, dan de add, daar c d uithalen, dan e f g h i j matchen na de branch, want de match na de branch is langer dan wat er in del staat.

// %%
val wA = HC.importXMLWitness("A", "<root>a b <subst><add>c d</add><del>e f</del></subst> e f g h i j</root>")
val wB = HC.importXMLWitness("B", "<root>a b c d e f g h i j</root>")
val collationGraph = HC.collate(wA,wB)
collationGraph.asASCIITable()
// Out:
// ┌───┬──┬──┬──────┬─────┬─┬──┬──┬──┬──┬──┬─┐
// │[A]│  │  │[+]  c│[+] d│ │  │  │  │  │  │ │
// │   │a │b │[-] e │[-] f│ │e │f │g │h │i │j│
// ├───┼──┼──┼──────┼─────┼─┼──┼──┼──┼──┼──┼─┤
// │[B]│a │b │c     │d    │ │e │f │g │h │i │j│
// └───┴──┴──┴──────┴─────┴─┴──┴──┴──┴──┴──┴─┘

// %%
collationGraph.asHtml()
// Out:
// <table border="1">
//             <tr><th style="background:lightgreen">A</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">b&nbsp;</span></td><td><sup><span style="background-color:lightblue">c&nbsp;</span></sup>&nbsp;<del>e&nbsp;</del></td><td><sup><span style="background-color:lightblue">d</span></sup>&nbsp;<del>f</del></td><td>&nbsp;</td><td><span style="background-color:lightblue">e&nbsp;</span></td><td><span style="background-color:lightblue">f&nbsp;</span></td><td><span style="background-color:lightblue">g&nbsp;</span></td><td><span style="background-color:lightblue">h&nbsp;</span></td><td><span style="background-color:lightblue">i&nbsp;</span></td><td><span style="background-color:lightblue">j</span></td></tr>
// <tr><th style="background:lightgreen">B</th><td><span style="background-color:lightblue">a&nbsp;</span></td><td><span style="background-color:lightblue">b&nbsp;</span></td><td><span style="background-color:lightblue">c&nbsp;</span></td><td><span style="background-color:lightblue">d&nbsp;</span></td><td></td><td><span style="background-color:lightblue">e&nbsp;</span></td><td><span style="background-color:lightblue">f&nbsp;</span></td><td><span style="background-color:lightblue">g&nbsp;</span></td><td><span style="background-color:lightblue">h&nbsp;</span></td><td><span style="background-color:lightblue">i&nbsp;</span></td><td><span style="background-color:lightblue">j</span></td></tr>
//             </table>

// %%
collationGraph.show()
