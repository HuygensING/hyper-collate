// %%
%use hyper-collate(1.3.5-SNAPSHOT-6)
// Out:
// Welcome to HyperCollate 1.3.5-SNAPSHOT-6
// Using GraphViz: dot - graphviz version 2.40.1 (20161225.0304)
// <style>div.output_area pre {white-space: pre;} .rendered_html td {border: 1px solid}</style>

// %%
val witA = HC.importXMLWitness("A", "<s>Murphy <subst><del>seized him by the arm.</del><add>stayed his hand.</add></subst></s>")
val witB = HC.importXMLWitness("B", "<s>Murphy stayed his hand.</s>")
val witC = HC.importXMLWitness("C", "<s>Murphy stayed the arm.</s>")

// %%
witA.show()

// %%
val collationGraph = HC.collate(witA,witB,witC)
collationGraph.show()
// Out:
// java.util.NoSuchElementException
// java.base/java.util.Arrays$ArrayItr.next(Arrays.java:4431)
// nl.knaw.huygens.hypercollate.collator.OptimalCollatedMatchListAlgorithm.neighborNodes_v2(OptimalCollatedMatchListAlgorithm.kt:115)
// nl.knaw.huygens.hypercollate.collator.OptimalCollatedMatchListAlgorithm.neighborNodes(OptimalCollatedMatchListAlgorithm.kt:63)
// nl.knaw.huygens.hypercollate.collator.OptimalCollatedMatchListAlgorithm.neighborNodes(OptimalCollatedMatchListAlgorithm.kt:31)
// eu.interedition.collatex.dekker.astar.AstarAlgorithm.aStar(AstarAlgorithm.java:54)
// nl.knaw.huygens.hypercollate.collator.OptimalCollatedMatchListAlgorithm.getOptimalCollatedMatchList(OptimalCollatedMatchListAlgorithm.kt:53)
// nl.knaw.huygens.hypercollate.collator.HyperCollator.optimized(HyperCollator.kt:168)
// nl.knaw.huygens.hypercollate.collator.HyperCollator.collate(HyperCollator.kt:125)
// nl.knaw.huygens.hypercollate.collator.HyperCollator.collate(HyperCollator.kt:48)
// ...
